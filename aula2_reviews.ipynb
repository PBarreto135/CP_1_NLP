# %%
# 0 - Libs
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import NaiveBayesClassifier

# 1 - Carregar dataset
df = pd.read_csv("reviews_smartphone.csv", sep='\t', encoding='latin-1')
reviews = df['Reviews'].tolist()
print(f"1 - Lista de Reviews:\n{reviews}")

# 2 - Pré-processamento
stop_words = set(stopwords.words('portuguese'))
lemmatizer = WordNetLemmatizer()

def preprocessar_texto(texto):
    texto = texto.lower()

    # Tokenização
    palavras = word_tokenize(texto, language='portuguese')

    # Remoção de stopwords
    palavras = [p for p in palavras if p not in stop_words and p.isalnum()]

    # Lematização
    palavras_lemmatizadas = [lemmatizer.lemmatize(p) for p in palavras]
    return palavras_lemmatizadas

reviews_processadas = [preprocessar_texto(r) for r in reviews]
print(f"\n2 - Reviews Processadas:\n{reviews_processadas}")

# 3 - Criar dataset de treino
## Rótulos de sentimento (True: positivo, False: negativo)
sentimentos = [
    True, False, False, False, True, True, True, False, True, False,
    True, True, True, True, True, False, True, True, True, True,
    True, True, True, True, False, True, True, True, False, True,
    True, False, False, True, False, True, True, True, False, False,
    True, True, True, True, True, True, False, True, True, True,
    True, True, False, False, False, True, True, True, True, False,
    True, True, True, True, False, True, True, True, True, True,
    True, True, False, True, True, True, False, True, True, False,
    True, False, True, True, True, True, False, True, False, True,
    True, True, True, False, True, False, True, True, True, False,
    True, True, False, True, True
]

def get_features(palavras):
    return dict([(palavra, True) for palavra in palavras])

training_set = [(get_features(r), s) for r, s in zip(reviews_processadas, sentimentos)]
print(f"\n3 - Dataset de Treino:\n{training_set}\n")

# 4 - Treinar classificador
classifier = NaiveBayesClassifier.train(training_set)

# 5 - Testar classificador
## Classificar reviews
print(f"5 - Teste de classificação de reviews:")
for item, texto in enumerate(reviews_processadas):
    features_nova_frase = get_features(texto)
    sentimento_predito = classifier.classify(features_nova_frase)
    print(f"Sentimento predito para '{reviews[item]}': {'Positivo' if sentimento_predito else 'Negativo'}")
# Out:
# 1 - Lista de Reviews:
# ['Vale cada centavo, superou minhas expectativas.', 'Não é ruim, mas esperava mais.', 'Regular, cumpre a função.', 'Aceitável para o preço que paguei.', 'Adorei o design e a velocidade do sistema.', 'Muito rápido e eficiente, recomendo!', 'Câmera incrível, fotos com ótima qualidade.', 'Design ok, desempenho dentro do esperado.', 'Tela com ótima resolução, muito satisfatória.', 'Regular, cumpre a função.', 'Muito rápido e eficiente, recomendo!', 'Tela com ótima resolução, muito satisfatória.', 'Melhor smartphone que já tive até hoje.', 'Tela com ótima resolução, muito satisfatória.', 'Melhor smartphone que já tive até hoje.', 'Esquenta demais durante o uso.', 'Vale cada centavo, superou minhas expectativas.', 'Atualizações constantes, ótimo suporte.', 'Muito rápido e eficiente, recomendo!', 'Adorei o design e a velocidade do sistema.', 'Câmera incrível, fotos com ótima qualidade.', 'Câmera incrível, fotos com ótima qualidade.', 'Muito rápido e eficiente, recomendo!', 'Carregamento super rápido, muito prático.', 'É um bom aparelho, mas nada demais.', 'Muito rápido e eficiente, recomendo!', 'Melhor smartphone que já tive até hoje.', 'Excelente desempenho e bateria de longa duração.', 'Aceitável para o preço que paguei.', 'Excelente desempenho e bateria de longa duração.', 'Tela com ótima resolução, muito satisfatória.', 'Regular, cumpre a função.', 'Design bonito, mas muito frágil.', 'Carregamento super rápido, muito prático.', 'Esquenta demais durante o uso.', 'Melhor smartphone que já tive até hoje.', 'Sistema fluido e sem travamentos.', 'Adorei o design e a velocidade do sistema.', 'Mais ou menos, poderia melhorar em alguns aspectos.', 'Preço alto para pouca entrega.', 'Tela com ótima resolução, muito satisfatória.', 'Muito rápido e eficiente, recomendo!', 'Excelente desempenho e bateria de longa duração.', 'Câmera incrível, fotos com ótima qualidade.', 'Muito rápido e eficiente, recomendo!', 'Sistema fluido e sem travamentos.', 'Bateria acaba muito rápido, decepcionante.', 'Câmera incrível, fotos com ótima qualidade.', 'Muito rápido e eficiente, recomendo!', 'Atualizações constantes, ótimo suporte.', 'Adorei o design e a velocidade do sistema.', 'Muito rápido e eficiente, recomendo!', 'Não recomendo, me arrependi da compra.', 'Câmera péssima em ambientes com pouca luz.', 'É um bom aparelho, mas nada demais.', 'Carregamento super rápido, muito prático.', 'Adorei o design e a velocidade do sistema.', 'Adorei o design e a velocidade do sistema.', 'Tela com ótima resolução, muito satisfatória.', 'Regular, cumpre a função.', 'Câmera incrível, fotos com ótima qualidade.', 'Sistema fluido e sem travamentos.', 'Atualizações constantes, ótimo suporte.', 'Atualizações constantes, ótimo suporte.', 'Melhor smartphone que já tive até hoje.', 'Melhor smartphone que já tive até hoje.', 'Bateria acaba muito rápido, decepcionante.', 'Melhor smartphone que já tive até hoje.', 'Vale cada centavo, superou minhas expectativas.', 'Excelente desempenho e bateria de longa duração.', 'Câmera incrível, fotos com ótima qualidade.', 'Atualizações constantes, ótimo suporte.', 'Entrega o que promete, mas sem surpresas.', 'Muito rápido e eficiente, recomendo!', 'Funciona bem para o dia a dia.', 'Esquenta demais durante o uso.', 'Som muito baixo e de má qualidade.', 'Tela com ótima resolução, muito satisfatória.', 'Sistema fluido e sem travamentos.', 'Melhor smartphone que já tive até hoje.', 'Sistema lento e cheio de bugs.', 'Design bonito, mas muito frágil.', 'Mais ou menos, poderia melhorar em alguns aspectos.', 'Câmera incrível, fotos com ótima qualidade.', 'Melhor smartphone que já tive até hoje.', 'Melhor smartphone que já tive até hoje.', 'Atualizações constantes, ótimo suporte.', 'Esquenta demais durante o uso.', 'Melhor smartphone que já tive até hoje.', 'Não é ruim, mas esperava mais.', 'Carregamento super rápido, muito prático.', 'Carregamento super rápido, muito prático.', 'Câmera incrível, fotos com ótima qualidade.', 'Esquenta demais durante o ...
#
# 2 - Reviews Processadas:
# [['vale', 'cada', 'centavo', 'superou', 'expectativas'], ['ruim', 'esperava'], ['regular', 'cumpre', 'função'], ['aceitável', 'preço', 'paguei'], ['adorei', 'design', 'velocidade', 'sistema'], ['rápido', 'eficiente', 'recomendo'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['design', 'ok', 'desempenho', 'dentro', 'esperado'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['regular', 'cumpre', 'função'], ['rápido', 'eficiente', 'recomendo'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['melhor', 'smartphone', 'hoje'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['melhor', 'smartphone', 'hoje'], ['esquenta', 'demais', 'durante', 'uso'], ['vale', 'cada', 'centavo', 'superou', 'expectativas'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['rápido', 'eficiente', 'recomendo'], ['adorei', 'design', 'velocidade', 'sistema'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['rápido', 'eficiente', 'recomendo'], ['carregamento', 'super', 'rápido', 'prático'], ['bom', 'aparelho', 'nada', 'demais'], ['rápido', 'eficiente', 'recomendo'], ['melhor', 'smartphone', 'hoje'], ['excelente', 'desempenho', 'bateria', 'longa', 'duração'], ['aceitável', 'preço', 'paguei'], ['excelente', 'desempenho', 'bateria', 'longa', 'duração'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['regular', 'cumpre', 'função'], ['design', 'bonito', 'frágil'], ['carregamento', 'super', 'rápido', 'prático'], ['esquenta', 'demais', 'durante', 'uso'], ['melhor', 'smartphone', 'hoje'], ['sistema', 'fluido', 'travamentos'], ['adorei', 'design', 'velocidade', 'sistema'], ['menos', 'poderia', 'melhorar', 'alguns', 'aspectos'], ['preço', 'alto', 'pouca', 'entrega'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['rápido', 'eficiente', 'recomendo'], ['excelente', 'desempenho', 'bateria', 'longa', 'duração'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['rápido', 'eficiente', 'recomendo'], ['sistema', 'fluido', 'travamentos'], ['bateria', 'acaba', 'rápido', 'decepcionante'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['rápido', 'eficiente', 'recomendo'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['adorei', 'design', 'velocidade', 'sistema'], ['rápido', 'eficiente', 'recomendo'], ['recomendo', 'arrependi', 'compra'], ['câmera', 'péssima', 'ambientes', 'pouca', 'luz'], ['bom', 'aparelho', 'nada', 'demais'], ['carregamento', 'super', 'rápido', 'prático'], ['adorei', 'design', 'velocidade', 'sistema'], ['adorei', 'design', 'velocidade', 'sistema'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['regular', 'cumpre', 'função'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['sistema', 'fluido', 'travamentos'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['melhor', 'smartphone', 'hoje'], ['melhor', 'smartphone', 'hoje'], ['bateria', 'acaba', 'rápido', 'decepcionante'], ['melhor', 'smartphone', 'hoje'], ['vale', 'cada', 'centavo', 'superou', 'expectativas'], ['excelente', 'desempenho', 'bateria', 'longa', 'duração'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['entrega', 'promete', 'surpresas'], ['rápido', 'eficiente', 'recomendo'], ['funciona', 'bem', 'dia', 'dia'], ['esquenta', 'demais', 'durante', 'uso'], ['som', 'baixo', 'má', 'qualidade'], ['tela', 'ótima', 'resolução', 'satisfatória'], ['sistema', 'fluido', 'travamentos'], ['melhor', 'smartphone', 'hoje'], ['sistema', 'lento', 'cheio', 'bug'], ['design', 'bonito', 'frágil'], ['menos', 'poderia', 'melhorar', 'alguns', 'aspectos'], ['câmera', 'incrível', 'fotos', 'ótima', 'qualidade'], ['melhor', 'smartphone', 'hoje'], ['melhor', 'smartphone', 'hoje'], ['atualizações', 'constantes', 'ótimo', 'suporte'], ['esquenta', 'demais', 'durante', 'uso'], ['melhor', 'smartphone', 'hoje'], ['ruim', 'esperava'], ['carregamento', 'super', 'rápido', 'prático'], ['carregamento', 'super', 'rá ...
#
# 3 - Dataset de Treino:
# [({'vale': True, 'cada': True, 'centavo': True, 'superou': True, 'expectativas': True}, True), ({'ruim': True, 'esperava': True}, False), ({'regular': True, 'cumpre': True, 'função': True}, False), ({'aceitável': True, 'preço': True, 'paguei': True}, False), ({'adorei': True, 'design': True, 'velocidade': True, 'sistema': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'câmera': True, 'incrível': True, 'fotos': True, 'ótima': True, 'qualidade': True}, True), ({'design': True, 'ok': True, 'desempenho': True, 'dentro': True, 'esperado': True}, False), ({'tela': True, 'ótima': True, 'resolução': True, 'satisfatória': True}, True), ({'regular': True, 'cumpre': True, 'função': True}, False), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'tela': True, 'ótima': True, 'resolução': True, 'satisfatória': True}, True), ({'melhor': True, 'smartphone': True, 'hoje': True}, True), ({'tela': True, 'ótima': True, 'resolução': True, 'satisfatória': True}, True), ({'melhor': True, 'smartphone': True, 'hoje': True}, True), ({'esquenta': True, 'demais': True, 'durante': True, 'uso': True}, False), ({'vale': True, 'cada': True, 'centavo': True, 'superou': True, 'expectativas': True}, True), ({'atualizações': True, 'constantes': True, 'ótimo': True, 'suporte': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'adorei': True, 'design': True, 'velocidade': True, 'sistema': True}, True), ({'câmera': True, 'incrível': True, 'fotos': True, 'ótima': True, 'qualidade': True}, True), ({'câmera': True, 'incrível': True, 'fotos': True, 'ótima': True, 'qualidade': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'carregamento': True, 'super': True, 'rápido': True, 'prático': True}, True), ({'bom': True, 'aparelho': True, 'nada': True, 'demais': True}, False), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'melhor': True, 'smartphone': True, 'hoje': True}, True), ({'excelente': True, 'desempenho': True, 'bateria': True, 'longa': True, 'duração': True}, True), ({'aceitável': True, 'preço': True, 'paguei': True}, False), ({'excelente': True, 'desempenho': True, 'bateria': True, 'longa': True, 'duração': True}, True), ({'tela': True, 'ótima': True, 'resolução': True, 'satisfatória': True}, True), ({'regular': True, 'cumpre': True, 'função': True}, False), ({'design': True, 'bonito': True, 'frágil': True}, False), ({'carregamento': True, 'super': True, 'rápido': True, 'prático': True}, True), ({'esquenta': True, 'demais': True, 'durante': True, 'uso': True}, False), ({'melhor': True, 'smartphone': True, 'hoje': True}, True), ({'sistema': True, 'fluido': True, 'travamentos': True}, True), ({'adorei': True, 'design': True, 'velocidade': True, 'sistema': True}, True), ({'menos': True, 'poderia': True, 'melhorar': True, 'alguns': True, 'aspectos': True}, False), ({'preço': True, 'alto': True, 'pouca': True, 'entrega': True}, False), ({'tela': True, 'ótima': True, 'resolução': True, 'satisfatória': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'excelente': True, 'desempenho': True, 'bateria': True, 'longa': True, 'duração': True}, True), ({'câmera': True, 'incrível': True, 'fotos': True, 'ótima': True, 'qualidade': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'sistema': True, 'fluido': True, 'travamentos': True}, True), ({'bateria': True, 'acaba': True, 'rápido': True, 'decepcionante': True}, False), ({'câmera': True, 'incrível': True, 'fotos': True, 'ótima': True, 'qualidade': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'atualizações': True, 'constantes': True, 'ótimo': True, 'suporte': True}, True), ({'adorei': True, 'design': True, 'velocidade': True, 'sistema': True}, True), ({'rápido': True, 'eficiente': True, 'recomendo': True}, True), ({'recomendo': True, 'arrependi': True, 'compra': True}, False), ({'câmera': True, 'péssima': Tr ...
#
# 5 - Teste de classificação de reviews:
# Sentimento predito para 'Vale cada centavo, superou minhas expectativas.': Positivo
# Sentimento predito para 'Não é ruim, mas esperava mais.': Negativo
# Sentimento predito para 'Regular, cumpre a função.': Negativo
# Sentimento predito para 'Aceitável para o preço que paguei.': Negativo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Design ok, desempenho dentro do esperado.': Negativo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Regular, cumpre a função.': Negativo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Vale cada centavo, superou minhas expectativas.': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Carregamento super rápido, muito prático.': Positivo
# Sentimento predito para 'É um bom aparelho, mas nada demais.': Negativo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Excelente desempenho e bateria de longa duração.': Positivo
# Sentimento predito para 'Aceitável para o preço que paguei.': Negativo
# Sentimento predito para 'Excelente desempenho e bateria de longa duração.': Positivo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Regular, cumpre a função.': Negativo
# Sentimento predito para 'Design bonito, mas muito frágil.': Negativo
# Sentimento predito para 'Carregamento super rápido, muito prático.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Sistema fluido e sem travamentos.': Positivo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Mais ou menos, poderia melhorar em alguns aspectos.': Negativo
# Sentimento predito para 'Preço alto para pouca entrega.': Negativo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Excelente desempenho e bateria de longa duração.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Sistema fluido e sem travamentos.': Positivo
# Sentimento predito para 'Bateria acaba muito rápido, decepcionante.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Não recomendo, me arrependi da compra.': Negativo
# Sentimento predito para 'Câmera péssima em ambientes com pouca luz.': Negativo
# Sentimento predito para 'É um bom aparelho, mas nada demais.': Negativo
# Sentimento predito para 'Carregamento super rápido, muito prático.': Positivo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Regular, cumpre a função.': Negativo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Sistema fluido e sem travamentos.': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Bateria acaba muito rápido, decepcionante.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Vale cada centavo, superou minhas expectativas.': Positivo
# Sentimento predito para 'Excelente desempenho e bateria de longa duração.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Entrega o que promete, mas sem surpresas.': Negativo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Funciona bem para o dia a dia.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Som muito baixo e de má qualidade.': Negativo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo
# Sentimento predito para 'Sistema fluido e sem travamentos.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Sistema lento e cheio de bugs.': Positivo
# Sentimento predito para 'Design bonito, mas muito frágil.': Negativo
# Sentimento predito para 'Mais ou menos, poderia melhorar em alguns aspectos.': Negativo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Atualizações constantes, ótimo suporte.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Não é ruim, mas esperava mais.': Negativo
# Sentimento predito para 'Carregamento super rápido, muito prático.': Positivo
# Sentimento predito para 'Carregamento super rápido, muito prático.': Positivo
# Sentimento predito para 'Câmera incrível, fotos com ótima qualidade.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Adorei o design e a velocidade do sistema.': Positivo
# Sentimento predito para 'Melhor smartphone que já tive até hoje.': Positivo
# Sentimento predito para 'Esquenta demais durante o uso.': Negativo
# Sentimento predito para 'Muito rápido e eficiente, recomendo!': Positivo
# Sentimento predito para 'Excelente desempenho e bateria de longa duração.': Positivo
# Sentimento predito para 'Tela com ótima resolução, muito satisfatória.': Positivo

# %%
## Classificar nova frase
frases = ['Gostei muito da bateria!', 'A tela é muito ruim', 'funciona bem', 'é ok']
for frase in frases:
    nova_frase_processada = preprocessar_texto(frase)
    features_nova_frase = get_features(nova_frase_processada)
    sentimento_predito = classifier.classify(features_nova_frase)
    print(f"Teste de Frase nova:")
    print(f"Sentimento predito para '{frase}': {'Positivo' if sentimento_predito else 'Negativo'}\n")
# Out:
# Teste de Frase nova:
# Sentimento predito para 'Gostei muito da bateria!': Positivo
#
# Teste de Frase nova:
# Sentimento predito para 'A tela é muito ruim': Positivo
#
# Teste de Frase nova:
# Sentimento predito para 'funciona bem': Positivo
#
# Teste de Frase nova:
# Sentimento predito para 'é ok': Negativo
